# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here
import pandas as pd

df1 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
df3 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")

# %%
df1.columns = [col.strip().replace(" ","_").lower() for col in df1.columns]
df1.dropna(how="all", inplace=True)
df1.loc[df1['gender'] == "female", "gender"] = "F"
df1.loc[df1['gender'] == "Femal", "gender"] = "F"
df1.loc[df1['gender'] == "Male", "gender"] = "M"
df1.loc[df1['st'] == "WA", "st"] = "Washington"
df1.loc[df1['st'] == "AZ", "st"] = "Arizona"
df1.loc[df1['st'] == "Cali", "st"] = "California"
df1.loc[df1['education'] == "Bachelors", "education"] = "Bachelor"
df1.loc[df1['vehicle_class'] == "Sports Car", "vehicle_class"] = "Luxury"
df1.loc[df1['vehicle_class'] == "Luxury SUV", "vehicle_class"] = "Luxury"
df1.loc[df1['vehicle_class'] == "Luxury Car", "vehicle_class"] = "Luxury"
df1["number_of_open_complaints"]=df1["number_of_open_complaints"].dropna().apply(lambda row: row.split("/")[1])
df1["number_of_open_complaints"] = df1["number_of_open_complaints"].astype("int")
df1["gender"] = df1["gender"].fillna("N/A")
df1["customer_lifetime_value"]= df1["customer_lifetime_value"].str.replace("%","")
df1["customer_lifetime_value"] = df1["customer_lifetime_value"].astype("float")
df1["customer_lifetime_value"]= df1["customer_lifetime_value"].fillna(df1["customer_lifetime_value"].mean())
df1["customer_lifetime_value"] = df1["customer_lifetime_value"].astype("int")
df1["income"] = df1["income"].astype("int")
df1["monthly_premium_auto"] = df1["monthly_premium_auto"].astype("int")
df1["total_claim_amount"] = df1["total_claim_amount"].astype("int")
df1.reset_index(drop=True)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    N/A                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327  California      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                      793690       0                  1000
# 1                      697953       0                    94
# 2                     1288743   48767                   108
# ...

# %%
df3.columns = [col.strip().replace(" ","_").lower() for col in df3.columns]
df3.dropna(how="all", inplace=True)
df3.rename(columns= {"state":"st"}, inplace = True)
df3.loc[df3['gender'] == "female", "gender"] = "F"
df3.loc[df3['gender'] == "Femal", "gender"] = "F"
df3.loc[df3['gender'] == "Male", "gender"] = "M"
df3.loc[df3['st'] == "WA", "st"] = "Washington"
df3.loc[df3['st'] == "AZ", "st"] = "Arizona"
df3.loc[df3['st'] == "Cali", "st"] = "California"
df3.loc[df3['education'] == "Bachelors", "education"] = "Bachelor"
df3.loc[df3['vehicle_class'] == "Sports Car", "vehicle_class"] = "Luxury"
df3.loc[df3['vehicle_class'] == "Luxury SUV", "vehicle_class"] = "Luxury"
df3.loc[df3['vehicle_class'] == "Luxury Car", "vehicle_class"] = "Luxury"
df3["number_of_open_complaints"] = df3["number_of_open_complaints"].astype("int")
df3["gender"] = df3["gender"].fillna("N/A")
df3["customer_lifetime_value"] = df3["customer_lifetime_value"].astype("float")
df3["customer_lifetime_value"]= df3["customer_lifetime_value"].fillna(df3["customer_lifetime_value"].mean())
df3["customer_lifetime_value"] = df3["customer_lifetime_value"].astype("int")
df3["income"] = df3["income"].astype("int")
df3["monthly_premium_auto"] = df3["monthly_premium_auto"].astype("int")
df3["total_claim_amount"] = df3["total_claim_amount"].astype("int")
df3.reset_index()
# Out:
#       index customer          st  customer_lifetime_value  \
# 0         0  SA25987  Washington                     3479
# 1         1  TB86706     Arizona                     2502
# 2         2  ZL73902      Nevada                     3265
# 3         3  KX23516  California                     4455
# 4         4  FN77294  California                     7704
# ...     ...      ...         ...                      ...
# 7065   7065  LA72316  California                    23405
# 7066   7066  PK87824  California                     3096
# 7067   7067  TD14365  California                     8163
# 7068   7068  UP19263  California                     7524
# 7069   7069  Y167826  California                     2611
#
#                  education gender  income  monthly_premium_auto  \
# 0     High School or Below      M       0                   104
# 1                   Master      M       0                    66
# 2                 Bachelor      F   25820                    82
# ...

# %%
df2.columns = [col.strip().replace(" ","_").lower() for col in df2.columns]
df2.dropna(how="all", inplace=True)
df2.loc[df2['gender'] == "female", "gender"] = "F"
df2.loc[df2['gender'] == "Femal", "gender"] = "F"
df2.loc[df2['gender'] == "Male", "gender"] = "M"
df2.loc[df2['st'] == "WA", "st"] = "Washington"
df2.loc[df2['st'] == "AZ", "st"] = "Arizona"
df2.loc[df2['st'] == "Cali", "st"] = "California"
df2.loc[df2['education'] == "Bachelors", "education"] = "Bachelor"
df2.loc[df2['vehicle_class'] == "Sports Car", "vehicle_class"] = "Luxury"
df2.loc[df2['vehicle_class'] == "Luxury SUV", "vehicle_class"] = "Luxury"
df2.loc[df2['vehicle_class'] == "Luxury Car", "vehicle_class"] = "Luxury"
df2["number_of_open_complaints"] = df2["number_of_open_complaints"].astype("int")
df2["gender"] = df2["gender"].fillna("N/A")
df2["customer_lifetime_value"]= df2["customer_lifetime_value"].str.replace("%","")
df2["customer_lifetime_value"] = df2["customer_lifetime_value"].astype("float")
df2["customer_lifetime_value"]= df2["customer_lifetime_value"].fillna(df2["customer_lifetime_value"].mean())
df2["customer_lifetime_value"] = df2["customer_lifetime_value"].astype("int")
df2["income"] = df2["income"].astype("int")
df2["monthly_premium_auto"] = df2["monthly_premium_auto"].astype("int")
df2["total_claim_amount"] = df2["total_claim_amount"].astype("int")
df2.reset_index()
# Out:
#      index customer          st gender education  customer_lifetime_value  \
# 0        0  GS98873     Arizona      F  Bachelor                   323912
# 1        1  CW49887  California      F    Master                   462680
# 2        2  MY31220  California      F   College                   899704
# 3        3  UH35128      Oregon      F   College                  2580706
# 4        4  WH52799     Arizona      F   College                   380812
# ..     ...      ...         ...    ...       ...                      ...
# 991    991  HV85198     Arizona      M    Master                   847141
# 992    992  BS91566     Arizona      F   College                   543121
# 993    993  IL40123      Nevada      F   College                   568964
# 994    994  MY32149  California      F    Master                   368672
# 995    995  SA91515  California      M  Bachelor                   399258
#
#      income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
df4 = pd.merge(df1,df2, how="outer")
df = pd.merge(df4,df3, how="outer")

# %%
df.isna().any()
# Out:
# customer                     False
# st                           False
# gender                       False
# education                    False
# customer_lifetime_value      False
# income                       False
# monthly_premium_auto         False
# number_of_open_complaints    False
# policy_type                  False
# vehicle_class                False
# total_claim_amount           False
# dtype: bool

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here

df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")

# %%
df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
df["total_claim_amount"] = round(df["total_claim_amount"],2)
saleby_channeldf = df.pivot_table(index="sales_channel", values=['total_claim_amount'], aggfunc='sum')
saleby_channeldf
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.88
# Branch                 1301204.34
# Call Center             926601.02
# Web                     706600.02

# %%
# The most successful sales channel is by Agent, and least is through the web. It can be assumed that more revenue can be gained through personal contact.

# %%
df["customer_lifetime_value"]
# Out:
# 0         4809.2
# 1         2228.5
# 2        14947.9
# 3        22332.4
# 4         9025.1
#           ...
# 10905    15563.4
# 10906     5259.4
# 10907    23893.3
# 10908    11972.0
# 10909     6857.5
# Name: customer_lifetime_value, Length: 10910, dtype: float64

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
customervalue_profile = df.pivot_table(index='education', columns='gender', values=['customer_lifetime_value'], aggfunc="mean")
round(customervalue_profile,2)
# Out:
#                      customer_lifetime_value
# gender                                     F        M
# education
# Bachelor                             7874.27  7703.60
# College                              7748.82  8052.46
# Doctor                               7328.50  7415.34
# High School or Below                 8675.22  8149.69
# Master                               8157.06  8168.83

# %%
# It can be understood that there is minimal difference from Male to Female, and education levels. The highest valued customers seem to be male with highschool or below education.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
